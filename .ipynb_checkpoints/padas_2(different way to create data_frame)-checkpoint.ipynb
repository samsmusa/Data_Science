# %%
import pandas as pd

# %%
df1 = pd.read_csv("weather_data.csv")
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# read_excel(io, sheet_name=0, header=0, names=None, index_col=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skipfooter=0, convert_float=True, mangle_dupe_cols=True, storage_options: Optional[Dict[str, Any]] = None)
#     Read an Excel file into a pandas DataFrame.
#
#     Supports `xls`, `xlsx`, `xlsm`, `xlsb`, `odf`, `ods` and `odt` file extensions
#     read from a local filesystem or URL. Supports an option to read
#     a single sheet or a list of sheets.
#
#     Parameters
#     ----------
#     io : str, bytes, ExcelFile, xlrd.Book, path object, or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
# ...

# %%
df2 = pd.read_excel('weather_data1.xlsx', index_col=0)
df2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-301ed9030ea5> in <module>
# ----> 1 df2 = pd.read_excel('weather_data1.xlsx', index_col=0)
#       2 df2
#
# c:\python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# c:\python\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     334     if not isinstance(io, ExcelFile):
# ...

# %%
weather_data = {
    'day':['1/1/2017','1/2/2017','1/3/2017','1/4/2017'],
    'temperature':[32,34,35,36],
    "windspeed":[6,7,8,9],
    'event':["Rain","sunny","snow","cold"]
}
df3 = pd.DataFrame(weather_data)
df3
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           34          7  sunny
# 2  1/3/2017           35          8   snow
# 3  1/4/2017           36          9   cold

# %%
weather_data = {
    ('1/1/2017',32,6,'rain'),
    ('1/3/2017',37,8,'sunny'),
    ('1/4/2017',39,9,'cold')
    
}

df4 = pd.DataFrame(data=weather_data , columns=['day','temperature','windspeed','event'])
df4
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   rain
# 1  1/3/2017           37          8  sunny
# 2  1/4/2017           39          9   cold

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['1','2','3','4'])
df
# Out:
#     1   2   3   4
# 0 NaN NaN NaN NaN
# 1 NaN NaN NaN NaN
# 2 NaN NaN NaN NaN
